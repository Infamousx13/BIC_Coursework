# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\infam\Desktop\Files\BIC HWU F21BC\banknote+authentication\data_banknote_authentication.txt", header= None)

# %%
df.columns = ['A','B','C','D','Output']

# %%
df.to_csv(r"C:\Users\infam\Desktop\Files\BIC HWU F21BC\banknote+authentication\data_banknote_authentication.csv", index = None)

# %%
df
# Out:
#             A         B        C        D  Output
# 0     3.62160   8.66610  -2.8073 -0.44699       0
# 1     4.54590   8.16740  -2.4586 -1.46210       0
# 2     3.86600  -2.63830   1.9242  0.10645       0
# 3     3.45660   9.52280  -4.0112 -3.59440       0
# 4     0.32924  -4.45520   4.5718 -0.98880       0
# ...       ...       ...      ...      ...     ...
# 1367  0.40614   1.34920  -1.4501 -0.55949       1
# 1368 -1.38870  -4.87730   6.4774  0.34179       1
# 1369 -3.75030 -13.45860  17.5932 -2.77710       1
# 1370 -3.56370  -8.38270  12.3930 -1.28230       1
# 1371 -2.54190  -0.65804   2.6842  1.19520       1
#
# [1372 rows x 5 columns]

# %%
dba = pd.read_csv(r"C:\Users\infam\Desktop\Files\BIC HWU F21BC\banknote+authentication\data_banknote_authentication.csv")

# %%
dba
# Out:
#             A         B        C        D  Output
# 0     3.62160   8.66610  -2.8073 -0.44699       0
# 1     4.54590   8.16740  -2.4586 -1.46210       0
# 2     3.86600  -2.63830   1.9242  0.10645       0
# 3     3.45660   9.52280  -4.0112 -3.59440       0
# 4     0.32924  -4.45520   4.5718 -0.98880       0
# ...       ...       ...      ...      ...     ...
# 1367  0.40614   1.34920  -1.4501 -0.55949       1
# 1368 -1.38870  -4.87730   6.4774  0.34179       1
# 1369 -3.75030 -13.45860  17.5932 -2.77710       1
# 1370 -3.56370  -8.38270  12.3930 -1.28230       1
# 1371 -2.54190  -0.65804   2.6842  1.19520       1
#
# [1372 rows x 5 columns]

# %%
sns.lineplot(data=dba['A'], label='A')
sns.lineplot(data=dba['Output'], label='O')
# Out:
# <Axes: ylabel='A'>

# %%
sns.lineplot(data=dba['B'], label='B')
sns.lineplot(data=dba['Output'], label='O')
# Out:
# <Axes: ylabel='B'>

# %%
sns.lineplot(data=dba['C'], label='C')
sns.lineplot(data=dba['Output'], label='O')
# Out:
# <Axes: ylabel='C'>

# %%
sns.lineplot(data=dba['D'], label='D')
sns.lineplot(data=dba['Output'], label='O')
# Out:
# <Axes: ylabel='D'>
